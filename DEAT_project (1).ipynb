# %%
import pandas as pd

# %%
salesframe_df = pd.read_csv('frame.csv')

# %%
salesmountain_df = pd.read_csv('mountain.csv')

# %%
salesframe_df
# Out:
#     ProductID                             Name    Price category  SalesID  \
# 0         210         HL Road Frame - Black 58  1431.50    Frame       35
# 1         211           HL Road Frame - Red 58  1431.50    Frame       74
# 2         223           HL Road Frame - Red 44  1431.50    Frame       36
# 3         223           HL Road Frame - Red 44  1431.50    Frame      162
# 4         224           HL Road Frame - Red 48  1431.50    Frame      113
# 5         225           HL Road Frame - Red 52  1431.50    Frame      121
# 6         232           LL Road Frame - Red 52   337.22    Frame      255
# 7         235           LL Road Frame - Red 62   337.22    Frame      173
# 8         239           ML Road Frame - Red 58   594.83    Frame       29
# 9         243         LL Road Frame - Black 52   337.22    Frame      149
# 10        243         LL Road Frame - Black 52   337.22    Frame      276
# 11        245    HL Mountain Frame - Silver 44  1364.50    Frame      190
# 12        245    HL Mountain Frame - Silver 44  1364.50    Frame      101
# 13        248     HL Mountain Frame - Black 42  1349.60    Frame       71
# 14        249     HL Mountain Frame - Black 44  1349.60    Frame       80
# 15        251     HL Mountain Frame - Black 46  1349.60    Frame       49
# 16        251     HL Mountain Frame - Black 46  1349.60    Frame      166
# 17        251     HL Mountain Frame - Black 46  1349.60    Frame      232
# 18        319     ML Mountain Frame - Black 38   348.76    Frame      184
# 19        337     ML Mountain Frame - Black 48   348.76    Frame      230
# 20        337     ML Mountain Frame - Black 48   348.76    Frame      288
# 21        339      ML Road Frame-W - Yellow 42   594.83    Frame      106
# 22        343         HL Road Frame - Black 44  1431.50    Frame      280
# 23        343         HL Road Frame - Black 44  1431.50    Frame      251
# 24        345         HL Road Frame - Black 52  1431.50    Frame      203
# 25        345         HL Road Frame - Black 52  1431.50    Frame      179
# 26        390     HL Touring Frame - Yellow 60  1003.91    Frame      175
# 27        390     HL Touring Frame - Yellow 60  1003.91    Frame      199
# 28        392     HL Touring Frame - Yellow 46  1003.91    Frame      277
# 29        392     HL Touring Frame - Yellow 46  1003.91    Frame       16
# 30        394     HL Touring Frame - Yellow 54  1003.91    Frame      220
# 31        395       HL Touring Frame - Blue 46  1003.91    Frame      114
# 32        397       HL Touring Frame - Blue 54  1003.91    Frame       40
# 33        398       HL Touring Frame - Blue 60  1003.91    Frame       54
# 34        402       LL Touring Frame - Blue 58   333.42    Frame      253
# 35        403       LL Touring Frame - Blue 62   333.42    Frame       17
# 36        407     LL Touring Frame - Yellow 58   333.42    Frame       20
# 37        407     LL Touring Frame - Yellow 58   333.42    Frame      249
# 38        411  ML Mountain Frame-W - Silver 46   364.09    Frame      152
# 39        422    LL Mountain Frame - Silver 42   264.05    Frame       12
# 40        432     LL Mountain Frame - Black 52   249.79    Frame       56
# 41        447  ML Mountain Frame-W - Silver 38   364.09    Frame       31
#
#     Quantity
# 0          2
# 1          9
# 2          1
# 3          1
# 4          6
# 5          9
# 6          3
# 7          9
# 8         10
# 9          8
# 10         7
# 11         8
# 12         6
# 13         1
# 14         6
# 15         9
# 16         8
# 17         7
# 18         5
# 19         9
# 20         7
# 21         5
# 22         9
# 23         4
# 24         6
# 25         1
# 26        10
# 27         4
# 28        10
# 29         6
# 30         4
# 31         5
# 32         1
# 33        10
# 34        10
# 35         6
# 36         9
# 37         4
# 38         2
# 39        10
# 40         4
# 41         4

# %%
salesmountain_df
# Out:
#     ProductID                       Name    Price  category  SalesID  Quantity
# 0          17          Mountain End Caps   590.40  Mountain       90         6
# 1          17          Mountain End Caps   590.40  Mountain      254         6
# 2         180            LL Mountain Rim   608.40  Mountain      246        10
# 3         181            ML Mountain Rim   914.40  Mountain      204         2
# 4         189  HL Mountain Seat Assembly   196.92  Mountain        2         9
# 5         189  HL Mountain Seat Assembly   196.92  Mountain      263         1
# 6         214      Mountain Bike Socks M     9.50  Mountain       43         9
# 7         214      Mountain Bike Socks M     9.50  Mountain      266         7
# 8         215      Mountain Bike Socks L     9.50  Mountain      168         1
# 9         215      Mountain Bike Socks L     9.50  Mountain       75         9
# 10        276     Mountain-100 Silver 38  3399.99  Mountain      126         4
# 11        276     Mountain-100 Silver 38  3399.99  Mountain      264        10
# 12        280      Mountain-100 Black 38  3374.99  Mountain      287         7
# 13        281      Mountain-100 Black 42  3374.99  Mountain      257         8
# 14        283      Mountain-100 Black 48  3374.99  Mountain       72         6
# 15        284     Mountain-200 Silver 38  2319.99  Mountain        3         2
# 16        285     Mountain-200 Silver 42  2319.99  Mountain      202         2
# 17        286     Mountain-200 Silver 46  2319.99  Mountain      144         1
# 18        287      Mountain-200 Black 38  2294.99  Mountain      185         9
# 19        287      Mountain-200 Black 38  2294.99  Mountain      161         7
# 20        291      Mountain-300 Black 40  1079.99  Mountain      208         1
# 21        293      Mountain-300 Black 48  1079.99  Mountain      115        10
# 22        314     ML Mountain Handlebars    61.92  Mountain      163         2
# 23        315     HL Mountain Handlebars   120.27  Mountain      102         6
# 24        373   Womens Mountain Shorts M    69.99  Mountain       59         2
# 25        373   Womens Mountain Shorts M    69.99  Mountain      103         4
# 26        374   Womens Mountain Shorts L    69.99  Mountain      117         1
# 27        383      Fender Set - Mountain    21.98  Mountain      159         8
# 28        383      Fender Set - Mountain    21.98  Mountain      267         3
# 29        413    LL Mountain Seat/Saddle    27.12  Mountain      192         5
# 30        413    LL Mountain Seat/Saddle    27.12  Mountain      228         1
# 31        414    ML Mountain Seat/Saddle    39.14  Mountain      128        10
# 32        414    ML Mountain Seat/Saddle    39.14  Mountain      294         6
# 33        426         Mountain Tire Tube     4.99  Mountain      215         3
# 34        433           LL Mountain Tire    24.99  Mountain      109         6
# 35        440          LL Mountain Pedal    40.49  Mountain      167         2
# 36        487   Mountain-400-W Silver 42   769.49  Mountain       27         7
# 37        488   Mountain-400-W Silver 46   769.49  Mountain      191         9
# 38        488   Mountain-400-W Silver 46   769.49  Mountain      186         7
# 39        490     Mountain-500 Silver 42   564.99  Mountain       24         5
# 40        490     Mountain-500 Silver 42   564.99  Mountain      295        10
# 41        491     Mountain-500 Silver 44   564.99  Mountain      182         8
# 42        492     Mountain-500 Silver 48   564.99  Mountain      214         9
# 43        492     Mountain-500 Silver 48   564.99  Mountain      297         9
# 44        493     Mountain-500 Silver 52   564.99  Mountain      226         1
# 45        494      Mountain-500 Black 40   539.99  Mountain      198         6
# 46        494      Mountain-500 Black 40   539.99  Mountain      177         2
# 47        498      Mountain-500 Black 52   539.99  Mountain        9        10

# %% [markdown]
# # Clean the data (Category frame)

# %% [markdown]
# using *duplicated()* to check if there is any duplicated rows.
# The duplicated method returns a series of Boolean True or False values. True if the row is a duplicate of a row above, and False otherwise.

# %%
salesframe_df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# dtype: bool

# %% [markdown]
# using *sum()* to count the number of duplicate rows (False is equivalent to 0 and True is equivalent to 1).

# %%
salesframe_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# using *info()* to check if there is any missing value (null) and datatype for each columns.

# %%
salesframe_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ProductID  42 non-null     int64
#  1   Name       42 non-null     object
#  2   Price      42 non-null     float64
#  3   category   42 non-null     object
#  4   SalesID    42 non-null     int64
#  5   Quantity   42 non-null     int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# Add a revenus coloumn.

# %%
salesframe_df['Revenue'] = salesframe_df['Price'] * salesframe_df['Quantity']

# %%
salesframe_df
# Out:
#     ProductID                             Name    Price category  SalesID  \
# 0         210         HL Road Frame - Black 58  1431.50    Frame       35
# 1         211           HL Road Frame - Red 58  1431.50    Frame       74
# 2         223           HL Road Frame - Red 44  1431.50    Frame       36
# 3         223           HL Road Frame - Red 44  1431.50    Frame      162
# 4         224           HL Road Frame - Red 48  1431.50    Frame      113
# 5         225           HL Road Frame - Red 52  1431.50    Frame      121
# 6         232           LL Road Frame - Red 52   337.22    Frame      255
# 7         235           LL Road Frame - Red 62   337.22    Frame      173
# 8         239           ML Road Frame - Red 58   594.83    Frame       29
# 9         243         LL Road Frame - Black 52   337.22    Frame      149
# 10        243         LL Road Frame - Black 52   337.22    Frame      276
# 11        245    HL Mountain Frame - Silver 44  1364.50    Frame      190
# 12        245    HL Mountain Frame - Silver 44  1364.50    Frame      101
# 13        248     HL Mountain Frame - Black 42  1349.60    Frame       71
# 14        249     HL Mountain Frame - Black 44  1349.60    Frame       80
# 15        251     HL Mountain Frame - Black 46  1349.60    Frame       49
# 16        251     HL Mountain Frame - Black 46  1349.60    Frame      166
# 17        251     HL Mountain Frame - Black 46  1349.60    Frame      232
# 18        319     ML Mountain Frame - Black 38   348.76    Frame      184
# 19        337     ML Mountain Frame - Black 48   348.76    Frame      230
# 20        337     ML Mountain Frame - Black 48   348.76    Frame      288
# 21        339      ML Road Frame-W - Yellow 42   594.83    Frame      106
# 22        343         HL Road Frame - Black 44  1431.50    Frame      280
# 23        343         HL Road Frame - Black 44  1431.50    Frame      251
# 24        345         HL Road Frame - Black 52  1431.50    Frame      203
# 25        345         HL Road Frame - Black 52  1431.50    Frame      179
# 26        390     HL Touring Frame - Yellow 60  1003.91    Frame      175
# 27        390     HL Touring Frame - Yellow 60  1003.91    Frame      199
# 28        392     HL Touring Frame - Yellow 46  1003.91    Frame      277
# 29        392     HL Touring Frame - Yellow 46  1003.91    Frame       16
# 30        394     HL Touring Frame - Yellow 54  1003.91    Frame      220
# 31        395       HL Touring Frame - Blue 46  1003.91    Frame      114
# 32        397       HL Touring Frame - Blue 54  1003.91    Frame       40
# 33        398       HL Touring Frame - Blue 60  1003.91    Frame       54
# 34        402       LL Touring Frame - Blue 58   333.42    Frame      253
# 35        403       LL Touring Frame - Blue 62   333.42    Frame       17
# 36        407     LL Touring Frame - Yellow 58   333.42    Frame       20
# 37        407     LL Touring Frame - Yellow 58   333.42    Frame      249
# 38        411  ML Mountain Frame-W - Silver 46   364.09    Frame      152
# 39        422    LL Mountain Frame - Silver 42   264.05    Frame       12
# 40        432     LL Mountain Frame - Black 52   249.79    Frame       56
# 41        447  ML Mountain Frame-W - Silver 38   364.09    Frame       31
#
#     Quantity   Revenue
# 0          2   2863.00
# 1          9  12883.50
# 2          1   1431.50
# 3          1   1431.50
# 4          6   8589.00
# 5          9  12883.50
# 6          3   1011.66
# 7          9   3034.98
# 8         10   5948.30
# 9          8   2697.76
# 10         7   2360.54
# 11         8  10916.00
# 12         6   8187.00
# 13         1   1349.60
# 14         6   8097.60
# 15         9  12146.40
# 16         8  10796.80
# 17         7   9447.20
# 18         5   1743.80
# 19         9   3138.84
# 20         7   2441.32
# 21         5   2974.15
# 22         9  12883.50
# 23         4   5726.00
# 24         6   8589.00
# 25         1   1431.50
# 26        10  10039.10
# 27         4   4015.64
# 28        10  10039.10
# 29         6   6023.46
# 30         4   4015.64
# 31         5   5019.55
# 32         1   1003.91
# 33        10  10039.10
# 34        10   3334.20
# 35         6   2000.52
# 36         9   3000.78
# 37         4   1333.68
# 38         2    728.18
# 39        10   2640.50
# 40         4    999.16
# 41         4   1456.36

# %% [markdown]
# Summarize revenue by Product in ascending order.

# %%
frame_summary = salesframe_df.groupby('Name').agg({
    'Quantity': 'sum',
    'Revenue': 'sum'
}).sort_values('Revenue', ascending=False).reset_index()

# %%
frame_summary = frame_summary.round(2)

# %%
frame_summary
# Out:
#                                Name  Quantity   Revenue
# 0      HL Mountain Frame - Black 46        24  32390.40
# 1     HL Mountain Frame - Silver 44        14  19103.00
# 2          HL Road Frame - Black 44        13  18609.50
# 3      HL Touring Frame - Yellow 46        16  16062.56
# 4      HL Touring Frame - Yellow 60        14  14054.74
# 5            HL Road Frame - Red 52         9  12883.50
# 6            HL Road Frame - Red 58         9  12883.50
# 7        HL Touring Frame - Blue 60        10  10039.10
# 8          HL Road Frame - Black 52         7  10020.50
# 9            HL Road Frame - Red 48         6   8589.00
# 10     HL Mountain Frame - Black 44         6   8097.60
# 11           ML Road Frame - Red 58        10   5948.30
# 12     ML Mountain Frame - Black 48        16   5580.16
# 13         LL Road Frame - Black 52        15   5058.30
# 14       HL Touring Frame - Blue 46         5   5019.55
# 15     LL Touring Frame - Yellow 58        13   4334.46
# 16     HL Touring Frame - Yellow 54         4   4015.64
# 17       LL Touring Frame - Blue 58        10   3334.20
# 18           LL Road Frame - Red 62         9   3034.98
# 19      ML Road Frame-W - Yellow 42         5   2974.15
# 20           HL Road Frame - Red 44         2   2863.00
# 21         HL Road Frame - Black 58         2   2863.00
# 22    LL Mountain Frame - Silver 42        10   2640.50
# 23       LL Touring Frame - Blue 62         6   2000.52
# 24     ML Mountain Frame - Black 38         5   1743.80
# 25  ML Mountain Frame-W - Silver 38         4   1456.36
# 26     HL Mountain Frame - Black 42         1   1349.60
# 27           LL Road Frame - Red 52         3   1011.66
# 28       HL Touring Frame - Blue 54         1   1003.91
# 29     LL Mountain Frame - Black 52         4    999.16
# 30  ML Mountain Frame-W - Silver 46         2    728.18

# %% [markdown]
# Total Quantity sold in category frame

# %%
frame_summary['Quantity'].sum()
# Out:
# np.int64(255)

# %% [markdown]
# Total Revenue sold in category frame

# %%
frame_summary['Revenue'].sum().round(2)
# Out:
# np.float64(220692.83)

# %% [markdown]
# Find product average price, max and min

# %%
salesframe_df['Price'].describe()
# Out:
# count      42.000000
# mean      904.376190
# std       478.898972
# min       249.790000
# 25%       348.760000
# 50%      1003.910000
# 75%      1364.500000
# max      1431.500000
# Name: Price, dtype: float64

# %% [markdown]
# Top 10 Best-Selling Products in category frame by Revenue

# %%
frametop10 = frame_summary.head(10)

# %%
frametop10
# Out:
#                             Name  Quantity   Revenue
# 0   HL Mountain Frame - Black 46        24  32390.40
# 1  HL Mountain Frame - Silver 44        14  19103.00
# 2       HL Road Frame - Black 44        13  18609.50
# 3   HL Touring Frame - Yellow 46        16  16062.56
# 4   HL Touring Frame - Yellow 60        14  14054.74
# 5         HL Road Frame - Red 52         9  12883.50
# 6         HL Road Frame - Red 58         9  12883.50
# 7     HL Touring Frame - Blue 60        10  10039.10
# 8       HL Road Frame - Black 52         7  10020.50
# 9         HL Road Frame - Red 48         6   8589.00

# %% [markdown]
# Total Revenue and Units Sold in category frame

# %%
total_revenue_frame = frame_summary['Revenue'].sum()

# %%
total_quantity_frame = frame_summary['Quantity'].sum()

# %%
total_revenue_frame
# Out:
# np.float64(220692.83000000002)

# %%
total_quantity_frame
# Out:
# np.int64(255)

# %% [markdown]
# Total revenue

# %%
total_revenue_frame
# Out:
# np.int64(220547)

# %% [markdown]
# % of Revenue for each product in total revenue

# %%
frame_summary['% of Total Sales'] = (frame_summary['Revenue'] / total_revenue_frame) * 100

# %% [markdown]
# Round it to 2 decimal place

# %%
frame_summary['% of Total Sales'] = frame_summary['% of Total Sales'].round(2)

# %%
frame_summary
# Out:
#                                Name  Quantity   Revenue  % of Total Sales
# 0      HL Mountain Frame - Black 46        24  32390.40             14.68
# 1     HL Mountain Frame - Silver 44        14  19103.00              8.66
# 2          HL Road Frame - Black 44        13  18609.50              8.43
# 3      HL Touring Frame - Yellow 46        16  16062.56              7.28
# 4      HL Touring Frame - Yellow 60        14  14054.74              6.37
# 5            HL Road Frame - Red 52         9  12883.50              5.84
# 6            HL Road Frame - Red 58         9  12883.50              5.84
# 7        HL Touring Frame - Blue 60        10  10039.10              4.55
# 8          HL Road Frame - Black 52         7  10020.50              4.54
# 9            HL Road Frame - Red 48         6   8589.00              3.89
# 10     HL Mountain Frame - Black 44         6   8097.60              3.67
# 11           ML Road Frame - Red 58        10   5948.30              2.70
# 12     ML Mountain Frame - Black 48        16   5580.16              2.53
# 13         LL Road Frame - Black 52        15   5058.30              2.29
# 14       HL Touring Frame - Blue 46         5   5019.55              2.27
# 15     LL Touring Frame - Yellow 58        13   4334.46              1.96
# 16     HL Touring Frame - Yellow 54         4   4015.64              1.82
# 17       LL Touring Frame - Blue 58        10   3334.20              1.51
# 18           LL Road Frame - Red 62         9   3034.98              1.38
# 19      ML Road Frame-W - Yellow 42         5   2974.15              1.35
# 20           HL Road Frame - Red 44         2   2863.00              1.30
# 21         HL Road Frame - Black 58         2   2863.00              1.30
# 22    LL Mountain Frame - Silver 42        10   2640.50              1.20
# 23       LL Touring Frame - Blue 62         6   2000.52              0.91
# 24     ML Mountain Frame - Black 38         5   1743.80              0.79
# 25  ML Mountain Frame-W - Silver 38         4   1456.36              0.66
# 26     HL Mountain Frame - Black 42         1   1349.60              0.61
# 27           LL Road Frame - Red 52         3   1011.66              0.46
# 28       HL Touring Frame - Blue 54         1   1003.91              0.45
# 29     LL Mountain Frame - Black 52         4    999.16              0.45
# 30  ML Mountain Frame-W - Silver 46         2    728.18              0.33

# %% [markdown]
# Sales pattern based on colour

# %%
import re

# %%
colors = ['Black', 'Silver', 'Red', 'Blue', 'Yellow']

# %%
def extract_color(name):
    for color in colors:
        if re.search(rf'\b{color}\b', name, re.IGNORECASE):
            return color
    return 'Unknown'

# %%
frame_summary['Color'] = frame_summary['Name'].apply(extract_color)

# %%
frame_summary
# Out:
#                                Name  Quantity   Revenue  % of Total Sales  \
# 0      HL Mountain Frame - Black 46        24  32390.40             14.68
# 1     HL Mountain Frame - Silver 44        14  19103.00              8.66
# 2          HL Road Frame - Black 44        13  18609.50              8.43
# 3      HL Touring Frame - Yellow 46        16  16062.56              7.28
# 4      HL Touring Frame - Yellow 60        14  14054.74              6.37
# 5            HL Road Frame - Red 52         9  12883.50              5.84
# 6            HL Road Frame - Red 58         9  12883.50              5.84
# 7        HL Touring Frame - Blue 60        10  10039.10              4.55
# 8          HL Road Frame - Black 52         7  10020.50              4.54
# 9            HL Road Frame - Red 48         6   8589.00              3.89
# 10     HL Mountain Frame - Black 44         6   8097.60              3.67
# 11           ML Road Frame - Red 58        10   5948.30              2.70
# 12     ML Mountain Frame - Black 48        16   5580.16              2.53
# 13         LL Road Frame - Black 52        15   5058.30              2.29
# 14       HL Touring Frame - Blue 46         5   5019.55              2.27
# 15     LL Touring Frame - Yellow 58        13   4334.46              1.96
# 16     HL Touring Frame - Yellow 54         4   4015.64              1.82
# 17       LL Touring Frame - Blue 58        10   3334.20              1.51
# 18           LL Road Frame - Red 62         9   3034.98              1.38
# 19      ML Road Frame-W - Yellow 42         5   2974.15              1.35
# 20           HL Road Frame - Red 44         2   2863.00              1.30
# 21         HL Road Frame - Black 58         2   2863.00              1.30
# 22    LL Mountain Frame - Silver 42        10   2640.50              1.20
# 23       LL Touring Frame - Blue 62         6   2000.52              0.91
# 24     ML Mountain Frame - Black 38         5   1743.80              0.79
# 25  ML Mountain Frame-W - Silver 38         4   1456.36              0.66
# 26     HL Mountain Frame - Black 42         1   1349.60              0.61
# 27           LL Road Frame - Red 52         3   1011.66              0.46
# 28       HL Touring Frame - Blue 54         1   1003.91              0.45
# 29     LL Mountain Frame - Black 52         4    999.16              0.45
# 30  ML Mountain Frame-W - Silver 46         2    728.18              0.33
#
#      Color
# 0    Black
# 1   Silver
# 2    Black
# 3   Yellow
# 4   Yellow
# 5      Red
# 6      Red
# 7     Blue
# 8    Black
# 9      Red
# 10   Black
# 11     Red
# 12   Black
# 13   Black
# 14    Blue
# 15  Yellow
# 16  Yellow
# 17    Blue
# 18     Red
# 19  Yellow
# 20     Red
# 21   Black
# 22  Silver
# 23    Blue
# 24   Black
# 25  Silver
# 26   Black
# 27     Red
# 28    Blue
# 29   Black
# 30  Silver

# %%
frame_summary.to_excel('frame_summary.xlsx', sheet_name='frame_summary')

# %% [markdown]
# Group the same product and revenue together

# %%
frame_summary.groupby('Name')['Revenue'].sum()
# Out:
# Name
# HL Mountain Frame - Black 42        1349
# HL Mountain Frame - Black 44        8094
# HL Mountain Frame - Black 46       32376
# HL Mountain Frame - Silver 44      19096
# HL Road Frame - Black 44           18603
# HL Road Frame - Black 52           10017
# HL Road Frame - Black 58            2862
# HL Road Frame - Red 44              2862
# HL Road Frame - Red 48              8586
# HL Road Frame - Red 52             12879
# HL Road Frame - Red 58             12879
# HL Touring Frame - Blue 46          5015
# HL Touring Frame - Blue 54          1003
# HL Touring Frame - Blue 60         10030
# HL Touring Frame - Yellow 46       16048
# HL Touring Frame - Yellow 54        4012
# HL Touring Frame - Yellow 60       14042
# LL Mountain Frame - Black 52         996
# LL Mountain Frame - Silver 42       2640
# LL Road Frame - Black 52            5055
# LL Road Frame - Red 52              1011
# LL Road Frame - Red 62              3033
# LL Touring Frame - Blue 58          3330
# LL Touring Frame - Blue 62          1998
# LL Touring Frame - Yellow 58        4329
# ML Mountain Frame - Black 38        1740
# ML Mountain Frame - Black 48        5568
# ML Mountain Frame-W - Silver 38     1456
# ML Mountain Frame-W - Silver 46      728
# ML Road Frame - Red 58              5940
# ML Road Frame-W - Yellow 42         2970
# Name: Revenue, dtype: int64

# %% [markdown]
# # Category mountain

# %% [markdown]
# Check for duplicate

# %%
salesmountain_df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# dtype: bool

# %% [markdown]
# Check for datatype

# %%
salesmountain_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ProductID  48 non-null     int64
#  1   Name       48 non-null     object
#  2   Price      48 non-null     float64
#  3   category   48 non-null     object
#  4   SalesID    48 non-null     int64
#  5   Quantity   48 non-null     int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 2.4+ KB

# %% [markdown]
# Add Revenue to a new column

# %%
salesmountain_df['Revenue'] = salesmountain_df['Price'] * salesmountain_df['Quantity']

# %%
salesmountain_df
# Out:
#     ProductID                       Name    Price  category  SalesID  \
# 0          17          Mountain End Caps   590.40  Mountain       90
# 1          17          Mountain End Caps   590.40  Mountain      254
# 2         180            LL Mountain Rim   608.40  Mountain      246
# 3         181            ML Mountain Rim   914.40  Mountain      204
# 4         189  HL Mountain Seat Assembly   196.92  Mountain        2
# 5         189  HL Mountain Seat Assembly   196.92  Mountain      263
# 6         214      Mountain Bike Socks M     9.50  Mountain       43
# 7         214      Mountain Bike Socks M     9.50  Mountain      266
# 8         215      Mountain Bike Socks L     9.50  Mountain      168
# 9         215      Mountain Bike Socks L     9.50  Mountain       75
# 10        276     Mountain-100 Silver 38  3399.99  Mountain      126
# 11        276     Mountain-100 Silver 38  3399.99  Mountain      264
# 12        280      Mountain-100 Black 38  3374.99  Mountain      287
# 13        281      Mountain-100 Black 42  3374.99  Mountain      257
# 14        283      Mountain-100 Black 48  3374.99  Mountain       72
# 15        284     Mountain-200 Silver 38  2319.99  Mountain        3
# 16        285     Mountain-200 Silver 42  2319.99  Mountain      202
# 17        286     Mountain-200 Silver 46  2319.99  Mountain      144
# 18        287      Mountain-200 Black 38  2294.99  Mountain      185
# 19        287      Mountain-200 Black 38  2294.99  Mountain      161
# 20        291      Mountain-300 Black 40  1079.99  Mountain      208
# 21        293      Mountain-300 Black 48  1079.99  Mountain      115
# 22        314     ML Mountain Handlebars    61.92  Mountain      163
# 23        315     HL Mountain Handlebars   120.27  Mountain      102
# 24        373   Womens Mountain Shorts M    69.99  Mountain       59
# 25        373   Womens Mountain Shorts M    69.99  Mountain      103
# 26        374   Womens Mountain Shorts L    69.99  Mountain      117
# 27        383      Fender Set - Mountain    21.98  Mountain      159
# 28        383      Fender Set - Mountain    21.98  Mountain      267
# 29        413    LL Mountain Seat/Saddle    27.12  Mountain      192
# 30        413    LL Mountain Seat/Saddle    27.12  Mountain      228
# 31        414    ML Mountain Seat/Saddle    39.14  Mountain      128
# 32        414    ML Mountain Seat/Saddle    39.14  Mountain      294
# 33        426         Mountain Tire Tube     4.99  Mountain      215
# 34        433           LL Mountain Tire    24.99  Mountain      109
# 35        440          LL Mountain Pedal    40.49  Mountain      167
# 36        487   Mountain-400-W Silver 42   769.49  Mountain       27
# 37        488   Mountain-400-W Silver 46   769.49  Mountain      191
# 38        488   Mountain-400-W Silver 46   769.49  Mountain      186
# 39        490     Mountain-500 Silver 42   564.99  Mountain       24
# 40        490     Mountain-500 Silver 42   564.99  Mountain      295
# 41        491     Mountain-500 Silver 44   564.99  Mountain      182
# 42        492     Mountain-500 Silver 48   564.99  Mountain      214
# 43        492     Mountain-500 Silver 48   564.99  Mountain      297
# 44        493     Mountain-500 Silver 52   564.99  Mountain      226
# 45        494      Mountain-500 Black 40   539.99  Mountain      198
# 46        494      Mountain-500 Black 40   539.99  Mountain      177
# 47        498      Mountain-500 Black 52   539.99  Mountain        9
#
#     Quantity   Revenue
# 0          6   3542.40
# 1          6   3542.40
# 2         10   6084.00
# 3          2   1828.80
# 4          9   1772.28
# 5          1    196.92
# 6          9     85.50
# 7          7     66.50
# 8          1      9.50
# 9          9     85.50
# 10         4  13599.96
# 11        10  33999.90
# 12         7  23624.93
# 13         8  26999.92
# 14         6  20249.94
# 15         2   4639.98
# 16         2   4639.98
# 17         1   2319.99
# 18         9  20654.91
# 19         7  16064.93
# 20         1   1079.99
# 21        10  10799.90
# 22         2    123.84
# 23         6    721.62
# 24         2    139.98
# 25         4    279.96
# 26         1     69.99
# 27         8    175.84
# 28         3     65.94
# 29         5    135.60
# 30         1     27.12
# 31        10    391.40
# 32         6    234.84
# 33         3     14.97
# 34         6    149.94
# 35         2     80.98
# 36         7   5386.43
# 37         9   6925.41
# 38         7   5386.43
# 39         5   2824.95
# 40        10   5649.90
# 41         8   4519.92
# 42         9   5084.91
# 43         9   5084.91
# 44         1    564.99
# 45         6   3239.94
# 46         2   1079.98
# 47        10   5399.90

# %% [markdown]
# Summarize revenue by Product in ascending order.

# %%
mountain_summary = salesmountain_df.groupby('Name').agg({
    'Quantity': 'sum',
    'Revenue': 'sum'
}).sort_values('Revenue', ascending=False).reset_index()

# %%
mountain_summary = mountain_summary.round(2)

# %%
mountain_summary
# Out:
#                          Name  Quantity   Revenue
# 0      Mountain-100 Silver 38        14  47599.86
# 1       Mountain-200 Black 38        16  36719.84
# 2       Mountain-100 Black 42         8  26999.92
# 3       Mountain-100 Black 38         7  23624.93
# 4       Mountain-100 Black 48         6  20249.94
# 5    Mountain-400-W Silver 46        16  12311.84
# 6       Mountain-300 Black 48        10  10799.90
# 7      Mountain-500 Silver 48        18  10169.82
# 8      Mountain-500 Silver 42        15   8474.85
# 9           Mountain End Caps        12   7084.80
# 10            LL Mountain Rim        10   6084.00
# 11      Mountain-500 Black 52        10   5399.90
# 12   Mountain-400-W Silver 42         7   5386.43
# 13     Mountain-200 Silver 38         2   4639.98
# 14     Mountain-200 Silver 42         2   4639.98
# 15     Mountain-500 Silver 44         8   4519.92
# 16      Mountain-500 Black 40         8   4319.92
# 17     Mountain-200 Silver 46         1   2319.99
# 18  HL Mountain Seat Assembly        10   1969.20
# 19            ML Mountain Rim         2   1828.80
# 20      Mountain-300 Black 40         1   1079.99
# 21     HL Mountain Handlebars         6    721.62
# 22    ML Mountain Seat/Saddle        16    626.24
# 23     Mountain-500 Silver 52         1    564.99
# 24   Womens Mountain Shorts M         6    419.94
# 25      Fender Set - Mountain        11    241.78
# 26    LL Mountain Seat/Saddle         6    162.72
# 27      Mountain Bike Socks M        16    152.00
# 28           LL Mountain Tire         6    149.94
# 29     ML Mountain Handlebars         2    123.84
# 30      Mountain Bike Socks L        10     95.00
# 31          LL Mountain Pedal         2     80.98
# 32   Womens Mountain Shorts L         1     69.99
# 33         Mountain Tire Tube         3     14.97

# %%
mountain_summary['Quantity'].sum()
# Out:
# np.int64(269)

# %%
mountain_summary['Revenue'].sum()
# Out:
# np.float64(249647.82)

# %% [markdown]
# Export data to excel

# %%
mountain_summary.to_excel('mountain_summary.xlsx', sheet_name='mountain_summary')

# %% [markdown]
# find product average price, max, and min.

# %%
salesmountain_df['Price'].describe()
# Out:
# count      48.000000
# mean      869.329375
# std      1097.566153
# min         4.990000
# 25%        40.152500
# 50%       564.990000
# 75%       955.797500
# max      3399.990000
# Name: Price, dtype: float64

# %% [markdown]
# Top 10 product sales

# %%
mountaintop10 = mountain_summary.head(10)

# %%
mountaintop10
# Out:
#                        Name  Quantity   Revenue
# 0    Mountain-100 Silver 38        14  47599.86
# 1     Mountain-200 Black 38        16  36719.84
# 2     Mountain-100 Black 42         8  26999.92
# 3     Mountain-100 Black 38         7  23624.93
# 4     Mountain-100 Black 48         6  20249.94
# 5  Mountain-400-W Silver 46        16  12311.84
# 6     Mountain-300 Black 48        10  10799.90
# 7    Mountain-500 Silver 48        18  10169.82
# 8    Mountain-500 Silver 42        15   8474.85
# 9         Mountain End Caps        12   7084.80

# %% [markdown]
# Total revenue

# %%
total_revenue_mountain = mountain_summary['Revenue'].sum()

# %%
total_revenue_mountain
# Out:
# np.float64(249647.82)

# %% [markdown]
# Total quantity

# %%
total_Quantity_mountain = mountain_summary['Quantity'].sum()

# %%
total_Quantity_mountain
# Out:
# np.int64(269)

# %% [markdown]
# % of Total Sales

# %%
mountain_summary['% of Total Sales'] = (mountain_summary['Revenue'] / total_revenue_mountain) * 100

# %%
mountain_summary['% of Total Sales'] = mountain_summary['% of Total Sales'].round(2)

# %%
mountain_summary
# Out:
#                          Name  Quantity   Revenue  % of Total Sales
# 0      Mountain-100 Silver 38        14  47599.86             19.07
# 1       Mountain-200 Black 38        16  36719.84             14.71
# 2       Mountain-100 Black 42         8  26999.92             10.82
# 3       Mountain-100 Black 38         7  23624.93              9.46
# 4       Mountain-100 Black 48         6  20249.94              8.11
# 5    Mountain-400-W Silver 46        16  12311.84              4.93
# 6       Mountain-300 Black 48        10  10799.90              4.33
# 7      Mountain-500 Silver 48        18  10169.82              4.07
# 8      Mountain-500 Silver 42        15   8474.85              3.39
# 9           Mountain End Caps        12   7084.80              2.84
# 10            LL Mountain Rim        10   6084.00              2.44
# 11      Mountain-500 Black 52        10   5399.90              2.16
# 12   Mountain-400-W Silver 42         7   5386.43              2.16
# 13     Mountain-200 Silver 38         2   4639.98              1.86
# 14     Mountain-200 Silver 42         2   4639.98              1.86
# 15     Mountain-500 Silver 44         8   4519.92              1.81
# 16      Mountain-500 Black 40         8   4319.92              1.73
# 17     Mountain-200 Silver 46         1   2319.99              0.93
# 18  HL Mountain Seat Assembly        10   1969.20              0.79
# 19            ML Mountain Rim         2   1828.80              0.73
# 20      Mountain-300 Black 40         1   1079.99              0.43
# 21     HL Mountain Handlebars         6    721.62              0.29
# 22    ML Mountain Seat/Saddle        16    626.24              0.25
# 23     Mountain-500 Silver 52         1    564.99              0.23
# 24   Womens Mountain Shorts M         6    419.94              0.17
# 25      Fender Set - Mountain        11    241.78              0.10
# 26    LL Mountain Seat/Saddle         6    162.72              0.07
# 27      Mountain Bike Socks M        16    152.00              0.06
# 28           LL Mountain Tire         6    149.94              0.06
# 29     ML Mountain Handlebars         2    123.84              0.05
# 30      Mountain Bike Socks L        10     95.00              0.04
# 31          LL Mountain Pedal         2     80.98              0.03
# 32   Womens Mountain Shorts L         1     69.99              0.03
# 33         Mountain Tire Tube         3     14.97              0.01

# %%
mountain_summary.to_excel('mountain_summary.xlsx', sheet_name='mountain_summary')

# %% [markdown]
# # Breakdown of Sales by Product

# %% [markdown]
# Read csv

# %%
Sales_df = pd.read_csv('sales.csv')

# %%
Sales_df
# Out:
#      ProductID  SalesID                   Name   Price  Quantity
# 0            2       81           Bearing Ball    0.80         3
# 1            2      123           Bearing Ball    0.80         2
# 2            4        5  Headset Ball Bearings    0.00         8
# 3            5      169                  Blade  189.60         1
# 4            8      145            HL Crankarm  319.00         8
# ..         ...      ...                    ...     ...       ...
# 295        494      177  Mountain-500 Black 40  539.99         2
# 296        498        9  Mountain-500 Black 52  539.99        10
# 297        501      284      HL Bottom Bracket  121.49         6
# 298        504      275      Road-750 Black 52  539.99         4
# 299        504      227      Road-750 Black 52  539.99         4
#
# [300 rows x 5 columns]

# %% [markdown]
# Check for duplicate

# %%
Sales_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Check datatype

# %%
Sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ProductID  300 non-null    int64
#  1   SalesID    300 non-null    int64
#  2   Name       300 non-null    object
#  3   Price      300 non-null    float64
#  4   Quantity   300 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 11.8+ KB

# %% [markdown]
# Find product with the price == 0

# %%
Sales_df.loc[Sales_df['Price'] == 0, 'Name']
# Out:
# 2         Headset Ball Bearings
# 5               Chainring Bolts
# 15                Flat Washer 1
# 16                Flat Washer 1
# 17                Flat Washer 2
# 23     Front Derailleur Linkage
# 25                 HL Grip Tape
# 26                 HL Grip Tape
# 44                    Hex Nut 1
# 45                    Hex Nut 1
# 47                    Hex Nut 2
# 56       External Lock Washer 3
# 57       External Lock Washer 4
# 58       External Lock Washer 5
# 60       Internal Lock Washer 1
# 61       Internal Lock Washer 1
# 62       Internal Lock Washer 1
# 83                Lock Washer 5
# 84                Lock Washer 5
# 85               Lock Washer 10
# 86               Lock Washer 10
# 87               Lock Washer 10
# 88                Lock Washer 8
# 90                Lock Washer 3
# 91                Lock Washer 3
# 100           Metal Tread Plate
# 108                 ML Road Rim
# 109                 HL Road Rim
# Name: Name, dtype: object

# %% [markdown]
# Remove data if the price is 0

# %%
Sales_df = Sales_df[Sales_df['Price'] != 0]

# %% [markdown]
# Add a new column 'Revenue'

# %%
Sales_df['revenue'] = Sales_df['Price'] * Sales_df['Quantity']
# Out:
# /tmp/ipython-input-217-179978850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_df['revenue'] = Sales_df['Price'] * Sales_df['Quantity']

# %% [markdown]
# Group the sales with the same product name.

# %%
Sales_summary = Sales_df.groupby('Name').agg({
    'Quantity': 'sum',
    'revenue': 'sum'
  }).sort_values('revenue', ascending=False).reset_index()

# %%
Sales_summary = Sales_summary.round(2)

# %%
Sales_summary
# Out:
#                              Name  Quantity   revenue
# 0          Mountain-100 Silver 38        14  47599.86
# 1                 Road-150 Red 48        12  42939.24
# 2                 Road-150 Red 44        11  39360.97
# 3           Mountain-200 Black 38        16  36719.84
# 4    HL Mountain Frame - Black 46        24  32390.40
# ..                            ...       ...       ...
# 200      Womens Mountain Shorts L         1     69.99
# 201        LL Touring Seat/Saddle         2     54.24
# 202            Mountain Tire Tube         3     14.97
# 203                  Bearing Ball         5      4.00
# 204           Patch Kit/8 Patches         1      2.29
#
# [205 rows x 3 columns]

# %% [markdown]
# Top 10 sales

# %%
sales_top10 = Sales_summary.head(10)

# %%
sales_top10.to_excel('Sales_top10.xlsx', sheet_name='Sales_top10')

# %%
sales_top10
# Out:
#                            Name  Quantity   revenue
# 0        Mountain-100 Silver 38        14  47599.86
# 1               Road-150 Red 48        12  42939.24
# 2               Road-150 Red 44        11  39360.97
# 3         Mountain-200 Black 38        16  36719.84
# 4  HL Mountain Frame - Black 46        24  32390.40
# 5         Mountain-100 Black 42         8  26999.92
# 6               Road-150 Red 52         7  25047.89
# 7          Touring-1000 Blue 50        10  23840.70
# 8          Road-350-W Yellow 40        14  23813.86
# 9         Mountain-100 Black 38         7  23624.93

# %% [markdown]
# Top 10 by quantity sold and top 10 by revenue

# %%
top_quantity = Sales_summary.sort_values(by='Quantity', ascending=False).head(10)

# Sort by revenue
top_revenue = Sales_summary.sort_values(by='revenue', ascending=False).head(10)

print("Top 10 by Quantity Sold:")
print(top_quantity)

print("\nTop 10 by Revenue:")
print(top_revenue)
# Out:
# Top 10 by Quantity Sold:
#                              Name  Quantity   revenue
# 4    HL Mountain Frame - Black 46        24  32390.40
# 17                      Lock Ring        20  16596.00
# 29         Mountain-500 Silver 48        18  10169.82
# 94                      Hex Nut 4        18   2844.00
# 27                 Handlebar Tube        17  10825.60
# 123                    Hex Nut 22        17   1298.80
# 160           LL Road Seat/Saddle        17    461.04
# 45                  Flat Washer 5        16   6681.60
# 18   HL Touring Frame - Yellow 46        16  16062.56
# 22       Mountain-400-W Silver 46        16  12311.84
#
# Top 10 by Revenue:
#                            Name  Quantity   revenue
# 0        Mountain-100 Silver 38        14  47599.86
# 1               Road-150 Red 48        12  42939.24
# 2               Road-150 Red 44        11  39360.97
# 3         Mountain-200 Black 38        16  36719.84
# 4  HL Mountain Frame - Black 46        24  32390.40
# 5         Mountain-100 Black 42         8  26999.92
# 6               Road-150 Red 52         7  25047.89
# 7          Touring-1000 Blue 50        10  23840.70
# 8          Road-350-W Yellow 40        14  23813.86
# 9         Mountain-100 Black 38         7  23624.93

# %% [markdown]
# # Customers loyalty

# %%
import pandas as pd

# %%
customers_df = pd.read_csv('customers.csv')

# %%
customers_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 295    False
# 296    False
# 297    False
# 298    False
# 299    False
# Length: 300, dtype: bool

# %%
customers_df
# Out:
#       SalesDate  SalesID  CustomerID FirstName LastName  ProductID  Quantity
# 0    2022-10-18       48           1     Aaron     Yang        294         4
# 1    2022-12-27      203           1     Aaron     Yang        345         6
# 2    2022-06-18       13           3      Adam    Young         20         6
# 3    2022-01-01       40           4      Alan       Ye        397         1
# 4    2022-06-28      235           4      Alan       Ye        218         9
# ..          ...      ...         ...       ...      ...        ...       ...
# 295  2022-05-30      243         357     Wyatt    Young         66         5
# 296  2022-08-27      197         358    Xavier    Young        381         3
# 297  2022-08-05       49         358    Xavier    Young        251         9
# 298  2022-11-29       20         359   Yolanda     Yuan        407         9
# 299  2022-07-02      228         360   Zachary     Yang        413         1
#
# [300 rows x 7 columns]

# %%
customers_df.iloc[0]
# Out:
# SalesDate     2022-10-18
# SalesID               48
# CustomerID             1
# FirstName          Aaron
# LastName            Yang
# ProductID            294
# Quantity               4
# Name: 0, dtype: object

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SalesDate   300 non-null    object
#  1   SalesID     300 non-null    int64
#  2   CustomerID  300 non-null    int64
#  3   FirstName   300 non-null    object
#  4   LastName    300 non-null    object
#  5   ProductID   300 non-null    int64
#  6   Quantity    300 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 16.5+ KB

# %% [markdown]
# Combine firstname and lastname to customername

# %%
customers_df['customerName'] = customers_df['FirstName'] + ' ' + customers_df['LastName']

# %%
customers_df = customers_df.drop(['FirstName', 'LastName'], axis=1)

# %% [markdown]
# Reorder the column

# %%
customers_df = customers_df[['SalesID' ,'SalesDate', 'CustomerID', 'customerName', 'ProductID', 'Quantity']]

# %%
customers_df
# Out:
#      SalesID   SalesDate  CustomerID  customerName  ProductID  Quantity
# 0         48  2022-10-18           1    Aaron Yang        294         4
# 1        203  2022-12-27           1    Aaron Yang        345         6
# 2         13  2022-06-18           3    Adam Young         20         6
# 3         40  2022-01-01           4       Alan Ye        397         1
# 4        235  2022-06-28           4       Alan Ye        218         9
# ..       ...         ...         ...           ...        ...       ...
# 295      243  2022-05-30         357   Wyatt Young         66         5
# 296      197  2022-08-27         358  Xavier Young        381         3
# 297       49  2022-08-05         358  Xavier Young        251         9
# 298       20  2022-11-29         359  Yolanda Yuan        407         9
# 299      228  2022-07-02         360  Zachary Yang        413         1
#
# [300 rows x 6 columns]

# %% [markdown]
# Count customers frequency

# %%
customers_counts = customers_df['customerName'].value_counts()

# %% [markdown]
# If customer counts = 1, they are one time customers

# %%
one_time_customers = (customer_counts == 1).sum()

# %%
one_time_customers
# Out:
# np.int64(125)

# %% [markdown]
# If customer counts > 1, they are repeat customers

# %%
repeat_customers = (customer_counts > 1).sum()

# %%
repeat_customers
# Out:
# np.int64(74)

# %%
total_customers = customer_counts.count()

# %%
percent_one_time = round(one_time_customers / total_customers * 100, 2)

# %%
percent_repeat = round(repeat_customers / total_customers * 100, 2)

# %%
percent_one_time
# Out:
# np.float64(62.81)

# %%
percent_repeat
# Out:
# np.float64(37.19)

# %% [markdown]
# Create a pie chart to show distribution of customers

# %%
import matplotlib.pyplot as plt

# %%
# Create a new figure for the pie chart
plt.figure(figsize=(6, 6))

# Pie chart data
labels = ['one_time_customers', 'repeat_customers']
sizes = [percent_one_time, percent_repeat]

# Create a pie chart

plt.pie(sizes,
        labels=labels,
        autopct='%1.1f%%',
        startangle=90
        )

# Add a title
plt.title("Customer Purchase Frequency")

# Display the pie chart
plt.show()

# %%
total_orders = customers_df['SalesID'].nunique()

# %%
average_orders_per_customer = total_orders / total_customers

# %%
total_orders
# Out:
# 300

# %%
total_customers
# Out:
# np.int64(199)

# %%
average_orders_per_customer
# Out:
# np.float64(1.5075376884422111)
